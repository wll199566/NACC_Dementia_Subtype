# %% [markdown]
# This notebook is used for visualizing the weights of the linear regression model. The weights is from 557 (features) to 4 (output classes).

# %%
import numpy as np

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
import sys
sys.path.insert(0, '../')

from models.linear_regression import LinearRegression

# %%
PATH_pretrained = "./models/model_6.pth"

# %%
### define a function to load in configuration  ###
import yaml

def load_config(filename):
    params = {}

    with open(filename) as f:
        params = yaml.load(f)

    return params

# %%
# define the model
params = load_config("./models/config.yaml")
model = LinearRegression(params["feature_dim"], params["output_dim"])
model.load_state_dict(torch.load(PATH_pretrained, map_location='cpu'))
# Out:
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %%
model.linear.weight
# Out:
# Parameter containing:
# tensor([[-3.0771e-02,  1.9845e-01,  3.7109e-04,  ...,  1.4883e-03,
#           1.8570e-04,  1.5613e-03],
#         [ 1.2075e-01, -4.8275e-01,  8.0865e-05,  ..., -1.4362e-03,
#          -3.0203e-04, -9.3305e-04],
#         [ 6.5207e-03, -3.7063e-02,  1.0472e-04,  ..., -3.4571e-03,
#           1.7285e-04,  5.2106e-04],
#         [ 3.3806e-03, -3.2478e-03,  2.4866e-04,  ...,  5.8791e-05,
#          -2.8904e-05,  9.4735e-07]], requires_grad=True)

# %%
# transder it into the numpy array and do without any gradient
with torch.no_grad():
    lr_weights = model.linear.weight.detach().numpy()

# %%
lr_weights
# Out:
# array([[-3.07707749e-02,  1.98448315e-01,  3.71087634e-04, ...,
#          1.48830039e-03,  1.85702011e-04,  1.56133319e-03],
#        [ 1.20745525e-01, -4.82749373e-01,  8.08647237e-05, ...,
#         -1.43617764e-03, -3.02034605e-04, -9.33045812e-04],
#        [ 6.52073650e-03, -3.70634049e-02,  1.04715480e-04, ...,
#         -3.45706777e-03,  1.72854459e-04,  5.21059206e-04],
#        [ 3.38060292e-03, -3.24778212e-03,  2.48657423e-04, ...,
#          5.87912800e-05, -2.89038508e-05,  9.47351964e-07]], dtype=float32)

# %% [markdown]
# I don't know how to make it clear, so let's get the weights based on each label and the order of the features we concatenated to construct the feature vector.

# %%
lr_weights[0, :].shape
# Out:
# (557,)

# %%
# !ls column_names/
# Out:
# all_column_names.pkl  categorical_values.pkl  continuous_column_names.pkl

# %%
# read in the entire column names and categorical column names
import pickle

folder_name = "./column_names/"
entire_column_filename = folder_name + "all_column_names.pkl"
#categorical_column_filename = folder_name + "categorical_column_names.pkl"
categorical_values_filename = folder_name + "categorical_values.pkl"

with open(entire_column_filename, 'rb') as fin:
    entire_column_names = pickle.load(fin)
#with open(categorical_column_filename, 'rb') as fin:
#    categorical_column_names = pickle.load(fin)
with open(categorical_values_filename, 'rb') as fin:
    categorical_values = pickle.load(fin)

# %%
categorical_values
# Out:
# {'PRIMLANG': array([-4,  1,  2,  3,  4,  5,  6]),
#  'NACCAHTN': array([-4,  0,  1]),
#  'DEPD': array([-4,  0,  1]),
#  'AGIT': array([-4,  0,  1]),
#  'ANX': array([-4,  0,  1]),
#  'ALCOCCAS': array([-4,  0,  1]),
#  'NACCANGI': array([-4,  0,  1]),
#  'OCD': array([-4,  0,  1,  2]),
#  'DISNSEV': array([-4,  1,  2,  3]),
#  'CRAFTCUE': array([-4,  0,  1]),
#  'EVENTS': array([-4,  0,  1,  2,  3]),
#  'ELATSEV': array([-4,  1,  2,  3]),
#  'APP': array([-4,  0,  1]),
#  'BILLS': array([-4,  0,  1,  2,  3]),
#  'NACCVASD': array([-4,  0,  1]),
#  'RBD': array([-4,  0,  1,  2]),
#  'NACCDBMD': array([-4,  0,  1]),
#  'DISN': array([-4,  0,  1]),
#  'HYPERTEN': array([-4,  0,  1,  2]),
#  'NACCAPOE': array([-4,  1,  2,  3,  4,  5,  6]),
#  'IRR': array([-4,  0,  1]),
#  'PAYATTN': array([-4,  0,  1,  2,  3]),
#  'NACCHTNC': array([-4,  0,  1]),
#  'PTSD': array([-4,  0,  1,  2]),
#  'NACCDIUR': array([-4,  0,  1]),
#  'DEPDSEV': array([-4,  1,  2,  3]),
#  'SHOPPING': array([-4,  0,  1,  2,  3]),
#  'DEPOTHR': array([-4,  0,  1]),
#  'NACCBETA': array([-4,  0,  1]),
#  'ALCFREQ': array([-4,  0,  1,  2,  3,  4]),
#  'APA': array([-4,  0,  1]),
#  'TRAUMBRF': array([-4,  0,  1,  2]),
#  'CBSTROKE': array([-4,  0,  1,  2]),
#  'ARTHLOEX': array([-4,  0,  1]),
#  'CVBYPASS': array([-4,  0,  1,  2]),
#  'ALCOHOL': array([-4,  0,  1,  2]),
#  'ARTHUNK': array([-4,  0,  1]),
#  'NACCACEI': array([-4,  0,  1]),
#  'CVHATT': array([-4,  0,  1,  2]),
#  'NACCNE4S': array([-4,  0,  1,  2]),
#  'INSOMN': array([-4,  0,  1,  2]),
#  'NACCAPSY': array([-4,  0,  1]),
#  'NITESEV': array([-4,  1,  2,  3]),
#  'B12DEF': array([-4,  0,  1,  2]),
#  'IRRSEV': array([-4,  1,  2,  3]),
#  'ANXSEV': array([-4,  1,  2,  3]),
#  'SEIZURES': array([-4,  0,  1,  2]),
#  'TOBAC30': array([-4,  0,  1]),
#  'STOVE': array([-4,  0,  1,  2,  3]),
#  'SCHIZ': array([-4,  0,  1,  2]),
#  'INCONTU': array([-4,  0,  1,  2]),
#  'TIAMULT': array([-4,  0,  1]),
#  'TRAUMCHR': array([-4,  0,  1,  2]),
#  'DEP2YRS': array([-4,  0,  1]),
#  'ARTHSPIN': array([-4,  0,  1]),
#  'ANYMEDS': array([-4,  0,  1]),
#  'TOBAC100': array([-4,  0,  1]),
#  'CVCHF': array([-4,  0,  1,  2]),
#  'INRELTO': array([-4,  1,  2,  3,  4,  5,  6,  7]),
#  'TBIEXTEN': array([-4,  0,  1,  2]),
#  'NACCEPMD': array([-4,  0,  1]),
#  'STROKMUL': array([-4,  0,  1]),
#  'PACKSPER': array([-4,  0,  1,  2,  3,  4,  5]),
#  'NITE': array([-4,  0,  1]),
#  'NPIQINF': array([-4,  1,  2,  3]),
#  'APPSEV': array([-4,  1,  2,  3]),
#  'GAMES': array([-4,  0,  1,  2,  3]),
#  'HALLSEV': array([-4,  1,  2,  3]),
#  'NACCAANX': array([-4,  0,  1]),
#  'NACCNIHR': array([-4,  1,  2,  3,  4,  5,  6]),
#  'APNEA': array([-4,  0,  1,  2]),
#  'CVANGIO': array([-4,  0,  1,  2]),
#  'ABUSOTHR': array([-4,  0,  1,  2]),
#  'TBIWOLOS': array([-4,  0,  1,  2]),
#  'HALL': array([-4,  0,  1]),
#  'NACCTBI': array([-4,  0,  1]),
#  'ARTHRIT': array([-4,  0,  1,  2]),
#  'INSEX': array([-4,  1,  2]),
#  'TRAVEL': array([-4,  0,  1,  2,  3]),
#  'OTHSLEEP': array([-4,  0,  1,  2]),
#  'BIPOLAR': array([-4,  0,  1,  2]),
#  'TRAUMEXT': array([-4,  0,  1,  2]),
#  'HATTMULT': array([-4,  0,  1]),
#  'PSYCDIS': array([-4,  0,  1,  2]),
#  'CVPACDEF': array([-4,  0,  1,  2]),
#  'HYPERCHO': array([-4,  0,  1,  2]),
#  'ANXIETY': array([-4,  0,  1,  2]),
#  'NCOTHR': array([-4,  0,  1,  2]),
#  'UDSBENRS': array([-4,  0,  1]),
#  'CVANGINA': array([-4,  0,  1,  2]),
#  'ELAT': array([-4,  0,  1]),
#  'DIABETES': array([-4,  0,  1,  2]),
#  'NACCNSD': array([-4,  0,  1]),
#  'TBI': array([-4,  0,  1,  2]),
#  'INCONTF': array([-4,  0,  1,  2]),
#  'HISPOR': array([-4,  1,  2,  3,  4,  5,  6, 50]),
#  'NACCCCBS': array([-4,  0,  1]),
#  'NPSYDEV': array([-4,  0,  1,  2]),
#  'DIABTYPE': array([-4,  1,  2,  3]),
#  'NACCFAM': array([-4,  0,  1]),
#  'AGITSEV': array([-4,  1,  2,  3]),
#  'TBIBRIEF': array([-4,  0,  1,  2]),
#  'DELSEV': array([-4,  1,  2,  3]),
#  'ARTHTYPE': array([-4,  1,  2,  3]),
#  'ARTHUPEX': array([-4,  0,  1]),
#  'APASEV': array([-4,  1,  2,  3]),
#  'MEALPREP': array([-4,  0,  1,  2,  3]),
#  'NACCEMD': array([-4,  0,  1]),
#  'SEX': array([1, 2]),
#  'NACCLIPL': array([-4,  0,  1]),
#  'DEL': array([-4,  0,  1]),
#  'REMDATES': array([-4,  0,  1,  2,  3]),
#  'CVOTHR': array([-4,  0,  1,  2]),
#  'CBTIA': array([-4,  0,  1,  2]),
#  'CVPACE': array([-4,  0,  1,  2]),
#  'TAXES': array([-4,  0,  1,  2,  3]),
#  'THYROID': array([-4,  0,  1,  2]),
#  'NACCAAAS': array([-4,  0,  1]),
#  'MOTSEV': array([-4,  1,  2,  3]),
#  'NACCADEP': array([-4,  0,  1]),
#  'CVHVALVE': array([-4,  0,  1,  2]),
#  'CVAFIB': array([-4,  0,  1,  2]),
#  'NACCNINR': array([-4,  1,  2,  3,  4,  5,  6]),
#  'MOT': array([-4,  0,  1]),
#  'HISPANIC': array([-4,  0,  1]),
#  'NACCAC': array([-4,  0,  1]),
#  'CSFABMD': array([-4,  1,  2]),
#  'CSFPTMD': array([-4.,  1.,  2.]),
#  'CSFTTMD': array([-4.,  1.,  2.])}

# %%
entire_column_names
# Out:
# ['NACCID',
#  'DATE',
#  'SEX',
#  'HISPANIC',
#  'HISPOR',
#  'PRIMLANG',
#  'EDUC',
#  'INSEX',
#  'NACCNINR',
#  'INEDUC',
#  'INRELTO',
#  'NACCFAM',
#  'ANYMEDS',
#  'TOBAC30',
#  'TOBAC100',
#  'SMOKYRS',
#  'PACKSPER',
#  'QUITSMOK',
#  'ALCOCCAS',
#  'ALCFREQ',
#  'CVHATT',
#  'HATTMULT',
#  'CVAFIB',
#  'CVANGIO',
#  'CVBYPASS',
#  'CVPACDEF',
#  'CVPACE',
#  'CVCHF',
#  'CVANGINA',
#  'CVHVALVE',
#  'CVOTHR',
#  'CBSTROKE',
#  'STROKMUL',
#  'CBTIA',
#  'TIAMULT',
#  'SEIZURES',
#  'NACCTBI',
#  'TBI',
#  'TBIBRIEF',
#  'TRAUMBRF',
#  'TBIEXTEN',
#  'TRAUMEXT',
#  'TBIWOLOS',
#  'TRAUMCHR',
#  'NCOTHR',
#  'DIABETES',
#  'DIABTYPE',
#  'HYPERTEN',
#  'HYPERCHO',
#  'B12DEF',
#  'THYROID',
#  'ARTHRIT',
#  'ARTHTYPE',
#  'ARTHUPEX',
#  'ARTHLOEX',
#  'ARTHSPIN',
#  'ARTHUNK',
#  'INCONTU',
#  'INCONTF',
#  'APNEA',
#  'RBD',
#  'INSOMN',
#  'OTHSLEEP',
#  'ALCOHOL',
#  'ABUSOTHR',
#  'PTSD',
#  'BIPOLAR',
#  'SCHIZ',
#  'DEP2YRS',
#  'DEPOTHR',
#  'ANXIETY',
#  'OCD',
#  'NPSYDEV',
#  'PSYCDIS',
#  'BPSYS',
#  'BPDIAS',
#  'CDRSUM',
#  'NPIQINF',
#  'DEL',
#  'DELSEV',
#  'HALL',
#  'HALLSEV',
#  'AGIT',
#  'AGITSEV',
#  'DEPD',
#  'DEPDSEV',
#  'ANX',
#  'ANXSEV',
#  'ELAT',
#  'ELATSEV',
#  'APA',
#  'APASEV',
#  'DISN',
#  'DISNSEV',
#  'IRR',
#  'IRRSEV',
#  'MOT',
#  'MOTSEV',
#  'NITE',
#  'NITESEV',
#  'APP',
#  'APPSEV',
#  'NACCGDS',
#  'BILLS',
#  'TAXES',
#  'SHOPPING',
#  'GAMES',
#  'STOVE',
#  'MEALPREP',
#  'EVENTS',
#  'PAYATTN',
#  'REMDATES',
#  'TRAVEL',
#  'NACCMMSE',
#  'LOGIMEM',
#  'MEMUNITS',
#  'MEMTIME',
#  'UDSBENTC',
#  'UDSBENTD',
#  'UDSBENRS',
#  'DIGIF',
#  'DIGIFLEN',
#  'DIGIB',
#  'DIGIBLEN',
#  'ANIMALS',
#  'VEG',
#  'TRAILA',
#  'TRAILARR',
#  'TRAILALI',
#  'TRAILB',
#  'TRAILBRR',
#  'TRAILBLI',
#  'WAIS',
#  'BOSTON',
#  'UDSVERFC',
#  'UDSVERFN',
#  'UDSVERNF',
#  'UDSVERLC',
#  'UDSVERLR',
#  'UDSVERLN',
#  'UDSVERTN',
#  'UDSVERTE',
#  'UDSVERTI',
#  'MOCATOTS',
#  'CRAFTVRS',
#  'CRAFTURS',
#  'DIGFORCT',
#  'DIGFORSL',
#  'DIGBACCT',
#  'DIGBACLS',
#  'CRAFTDVR',
#  'CRAFTDRE',
#  'CRAFTDTI',
#  'CRAFTCUE',
#  'MINTTOTS',
#  'MINTTOTW',
#  'MINTSCNG',
#  'MINTSCNC',
#  'MINTPCNG',
#  'MINTPCNC',
#  'NACCAGEB',
#  'NACCNIHR',
#  'NACCAGE',
#  'NACCAAAS',
#  'NACCAANX',
#  'NACCAC',
#  'NACCACEI',
#  'NACCADEP',
#  'NACCAHTN',
#  'NACCAMD',
#  'NACCANGI',
#  'NACCAPSY',
#  'NACCBETA',
#  'NACCCCBS',
#  'NACCDBMD',
#  'NACCDIUR',
#  'NACCEMD',
#  'NACCEPMD',
#  'NACCHTNC',
#  'NACCLIPL',
#  'NACCNSD',
#  'NACCVASD',
#  'NACCBMI',
#  'NACCNE4S',
#  'NACCAPOE',
#  'CSFABETA',
#  'CSFPTAU',
#  'CSFTTAU',
#  'CSFABMD',
#  'CSFPTMD',
#  'CSFTTMD']

# %%
# since there are "NACCID" and "DATE" column, we remove them first
entire_column_names.remove("NACCID")
entire_column_names.remove("DATE")

# %%
# get the whole feature names for each entry
whole_feature_names_list= []  # store names for each entry
for col in entire_column_names:
    if col in list(categorical_values.keys()):
        # if this is a categorical name
        for value in list(categorical_values[col]):
            whole_feature_names_list.append(col+str(value))
    else:
        whole_feature_names_list.append(col)

# %%
len(whole_feature_names_list)
# Out:
# 557

# %%
whole_feature_names_list
# Out:
# ['SEX1',
#  'SEX2',
#  'HISPANIC-4',
#  'HISPANIC0',
#  'HISPANIC1',
#  'HISPOR-4',
#  'HISPOR1',
#  'HISPOR2',
#  'HISPOR3',
#  'HISPOR4',
#  'HISPOR5',
#  'HISPOR6',
#  'HISPOR50',
#  'PRIMLANG-4',
#  'PRIMLANG1',
#  'PRIMLANG2',
#  'PRIMLANG3',
#  'PRIMLANG4',
#  'PRIMLANG5',
#  'PRIMLANG6',
#  'EDUC',
#  'INSEX-4',
#  'INSEX1',
#  'INSEX2',
#  'NACCNINR-4',
#  'NACCNINR1',
#  'NACCNINR2',
#  'NACCNINR3',
#  'NACCNINR4',
#  'NACCNINR5',
#  'NACCNINR6',
#  'INEDUC',
#  'INRELTO-4',
#  'INRELTO1',
#  'INRELTO2',
#  'INRELTO3',
#  'INRELTO4',
#  'INRELTO5',
#  'INRELTO6',
#  'INRELTO7',
#  'NACCFAM-4',
#  'NACCFAM0',
#  'NACCFAM1',
#  'ANYMEDS-4',
#  'ANYMEDS0',
#  'ANYMEDS1',
#  'TOBAC30-4',
#  'TOBAC300',
#  'TOBAC301',
#  'TOBAC100-4',
#  'TOBAC1000',
#  'TOBAC1001',
#  'SMOKYRS',
#  'PACKSPER-4',
#  'PACKSPER0',
#  'PACKSPER1',
#  'PACKSPER2',
#  'PACKSPER3',
#  'PACKSPER4',
#  'PACKSPER5',
#  'QUITSMOK',
#  'ALCOCCAS-4',
#  'ALCOCCAS0',
#  'ALCOCCAS1',
#  'ALCFREQ-4',
#  'ALCFREQ0',
#  'ALCFREQ1',
#  'ALCFREQ2',
#  'ALCFREQ3',
#  'ALCFREQ4',
#  'CVHATT-4',
#  'CVHATT0',
#  'CVHATT1',
#  'CVHATT2',
#  'HATTMULT-4',
#  'HATTMULT0',
#  'HATTMULT1',
#  'CVAFIB-4',
#  'CVAFIB0',
#  'CVAFIB1',
#  'CVAFIB2',
#  'CVANGIO-4',
#  'CVANGIO0',
#  'CVANGIO1',
#  'CVANGIO2',
#  'CVBYPASS-4',
#  'CVBYPASS0',
#  'CVBYPASS1',
#  'CVBYPASS2',
#  'CVPACDEF-4',
#  'CVPACDEF0',
#  'CVPACDEF1',
#  'CVPACDEF2',
#  'CVPACE-4',
#  'CVPACE0',
#  'CVPACE1',
#  'CVPACE2',
#  'CVCHF-4',
#  'CVCHF0',
#  'CVCHF1',
#  'CVCHF2',
#  'CVANGINA-4',
#  'CVANGINA0',
#  'CVANGINA1',
#  'CVANGINA2',
#  'CVHVALVE-4',
#  'CVHVALVE0',
#  'CVHVALVE1',
#  'CVHVALVE2',
#  'CVOTHR-4',
#  'CVOTHR0',
#  'CVOTHR1',
#  'CVOTHR2',
#  'CBSTROKE-4',
#  'CBSTROKE0',
#  'CBSTROKE1',
#  'CBSTROKE2',
#  'STROKMUL-4',
#  'STROKMUL0',
#  'STROKMUL1',
#  'CBTIA-4',
#  'CBTIA0',
#  'CBTIA1',
#  'CBTIA2',
#  'TIAMULT-4',
#  'TIAMULT0',
#  'TIAMULT1',
#  'SEIZURES-4',
#  'SEIZURES0',
#  'SEIZURES1',
#  'SEIZURES2',
#  'NACCTBI-4',
#  'NACCTBI0',
#  'NACCTBI1',
#  'TBI-4',
#  'TBI0',
#  'TBI1',
#  'TBI2',
#  'TBIBRIEF-4',
#  'TBIBRIEF0',
#  'TBIBRIEF1',
#  'TBIBRIEF2',
#  'TRAUMBRF-4',
#  'TRAUMBRF0',
#  'TRAUMBRF1',
#  'TRAUMBRF2',
#  'TBIEXTEN-4',
#  'TBIEXTEN0',
#  'TBIEXTEN1',
#  'TBIEXTEN2',
#  'TRAUMEXT-4',
#  'TRAUMEXT0',
#  'TRAUMEXT1',
#  'TRAUMEXT2',
#  'TBIWOLOS-4',
#  'TBIWOLOS0',
#  'TBIWOLOS1',
#  'TBIWOLOS2',
#  'TRAUMCHR-4',
#  'TRAUMCHR0',
#  'TRAUMCHR1',
#  'TRAUMCHR2',
#  'NCOTHR-4',
#  'NCOTHR0',
#  'NCOTHR1',
#  'NCOTHR2',
#  'DIABETES-4',
#  'DIABETES0',
#  'DIABETES1',
#  'DIABETES2',
#  'DIABTYPE-4',
#  'DIABTYPE1',
#  'DIABTYPE2',
#  'DIABTYPE3',
#  'HYPERTEN-4',
#  'HYPERTEN0',
#  'HYPERTEN1',
#  'HYPERTEN2',
#  'HYPERCHO-4',
#  'HYPERCHO0',
#  'HYPERCHO1',
#  'HYPERCHO2',
#  'B12DEF-4',
#  'B12DEF0',
#  'B12DEF1',
#  'B12DEF2',
#  'THYROID-4',
#  'THYROID0',
#  'THYROID1',
#  'THYROID2',
#  'ARTHRIT-4',
#  'ARTHRIT0',
#  'ARTHRIT1',
#  'ARTHRIT2',
#  'ARTHTYPE-4',
#  'ARTHTYPE1',
#  'ARTHTYPE2',
#  'ARTHTYPE3',
#  'ARTHUPEX-4',
#  'ARTHUPEX0',
#  'ARTHUPEX1',
#  'ARTHLOEX-4',
#  'ARTHLOEX0',
#  'ARTHLOEX1',
#  'ARTHSPIN-4',
#  'ARTHSPIN0',
#  'ARTHSPIN1',
#  'ARTHUNK-4',
#  'ARTHUNK0',
#  'ARTHUNK1',
#  'INCONTU-4',
#  'INCONTU0',
#  'INCONTU1',
#  'INCONTU2',
#  'INCONTF-4',
#  'INCONTF0',
#  'INCONTF1',
#  'INCONTF2',
#  'APNEA-4',
#  'APNEA0',
#  'APNEA1',
#  'APNEA2',
#  'RBD-4',
#  'RBD0',
#  'RBD1',
#  'RBD2',
#  'INSOMN-4',
#  'INSOMN0',
#  'INSOMN1',
#  'INSOMN2',
#  'OTHSLEEP-4',
#  'OTHSLEEP0',
#  'OTHSLEEP1',
#  'OTHSLEEP2',
#  'ALCOHOL-4',
#  'ALCOHOL0',
#  'ALCOHOL1',
#  'ALCOHOL2',
#  'ABUSOTHR-4',
#  'ABUSOTHR0',
#  'ABUSOTHR1',
#  'ABUSOTHR2',
#  'PTSD-4',
#  'PTSD0',
#  'PTSD1',
#  'PTSD2',
#  'BIPOLAR-4',
#  'BIPOLAR0',
#  'BIPOLAR1',
#  'BIPOLAR2',
#  'SCHIZ-4',
#  'SCHIZ0',
#  'SCHIZ1',
#  'SCHIZ2',
#  'DEP2YRS-4',
#  'DEP2YRS0',
#  'DEP2YRS1',
#  'DEPOTHR-4',
#  'DEPOTHR0',
#  'DEPOTHR1',
#  'ANXIETY-4',
#  'ANXIETY0',
#  'ANXIETY1',
#  'ANXIETY2',
#  'OCD-4',
#  'OCD0',
#  'OCD1',
#  'OCD2',
#  'NPSYDEV-4',
#  'NPSYDEV0',
#  'NPSYDEV1',
#  'NPSYDEV2',
#  'PSYCDIS-4',
#  'PSYCDIS0',
#  'PSYCDIS1',
#  'PSYCDIS2',
#  'BPSYS',
#  'BPDIAS',
#  'CDRSUM',
#  'NPIQINF-4',
#  'NPIQINF1',
#  'NPIQINF2',
#  'NPIQINF3',
#  'DEL-4',
#  'DEL0',
#  'DEL1',
#  'DELSEV-4',
#  'DELSEV1',
#  'DELSEV2',
#  'DELSEV3',
#  'HALL-4',
#  'HALL0',
#  'HALL1',
#  'HALLSEV-4',
#  'HALLSEV1',
#  'HALLSEV2',
#  'HALLSEV3',
#  'AGIT-4',
#  'AGIT0',
#  'AGIT1',
#  'AGITSEV-4',
#  'AGITSEV1',
#  'AGITSEV2',
#  'AGITSEV3',
#  'DEPD-4',
#  'DEPD0',
#  'DEPD1',
#  'DEPDSEV-4',
#  'DEPDSEV1',
#  'DEPDSEV2',
#  'DEPDSEV3',
#  'ANX-4',
#  'ANX0',
#  'ANX1',
#  'ANXSEV-4',
#  'ANXSEV1',
#  'ANXSEV2',
#  'ANXSEV3',
#  'ELAT-4',
#  'ELAT0',
#  'ELAT1',
#  'ELATSEV-4',
#  'ELATSEV1',
#  'ELATSEV2',
#  'ELATSEV3',
#  'APA-4',
#  'APA0',
#  'APA1',
#  'APASEV-4',
#  'APASEV1',
#  'APASEV2',
#  'APASEV3',
#  'DISN-4',
#  'DISN0',
#  'DISN1',
#  'DISNSEV-4',
#  'DISNSEV1',
#  'DISNSEV2',
#  'DISNSEV3',
#  'IRR-4',
#  'IRR0',
#  'IRR1',
#  'IRRSEV-4',
#  'IRRSEV1',
#  'IRRSEV2',
#  'IRRSEV3',
#  'MOT-4',
#  'MOT0',
#  'MOT1',
#  'MOTSEV-4',
#  'MOTSEV1',
#  'MOTSEV2',
#  'MOTSEV3',
#  'NITE-4',
#  'NITE0',
#  'NITE1',
#  'NITESEV-4',
#  'NITESEV1',
#  'NITESEV2',
#  'NITESEV3',
#  'APP-4',
#  'APP0',
#  'APP1',
#  'APPSEV-4',
#  'APPSEV1',
#  'APPSEV2',
#  'APPSEV3',
#  'NACCGDS',
#  'BILLS-4',
#  'BILLS0',
#  'BILLS1',
#  'BILLS2',
#  'BILLS3',
#  'TAXES-4',
#  'TAXES0',
#  'TAXES1',
#  'TAXES2',
#  'TAXES3',
#  'SHOPPING-4',
#  'SHOPPING0',
#  'SHOPPING1',
#  'SHOPPING2',
#  'SHOPPING3',
#  'GAMES-4',
#  'GAMES0',
#  'GAMES1',
#  'GAMES2',
#  'GAMES3',
#  'STOVE-4',
#  'STOVE0',
#  'STOVE1',
#  'STOVE2',
#  'STOVE3',
#  'MEALPREP-4',
#  'MEALPREP0',
#  'MEALPREP1',
#  'MEALPREP2',
#  'MEALPREP3',
#  'EVENTS-4',
#  'EVENTS0',
#  'EVENTS1',
#  'EVENTS2',
#  'EVENTS3',
#  'PAYATTN-4',
#  'PAYATTN0',
#  'PAYATTN1',
#  'PAYATTN2',
#  'PAYATTN3',
#  'REMDATES-4',
#  'REMDATES0',
#  'REMDATES1',
#  'REMDATES2',
#  'REMDATES3',
#  'TRAVEL-4',
#  'TRAVEL0',
#  'TRAVEL1',
#  'TRAVEL2',
#  'TRAVEL3',
#  'NACCMMSE',
#  'LOGIMEM',
#  'MEMUNITS',
#  'MEMTIME',
#  'UDSBENTC',
#  'UDSBENTD',
#  'UDSBENRS-4',
#  'UDSBENRS0',
#  'UDSBENRS1',
#  'DIGIF',
#  'DIGIFLEN',
#  'DIGIB',
#  'DIGIBLEN',
#  'ANIMALS',
#  'VEG',
#  'TRAILA',
#  'TRAILARR',
#  'TRAILALI',
#  'TRAILB',
#  'TRAILBRR',
#  'TRAILBLI',
#  'WAIS',
#  'BOSTON',
#  'UDSVERFC',
#  'UDSVERFN',
#  'UDSVERNF',
#  'UDSVERLC',
#  'UDSVERLR',
#  'UDSVERLN',
#  'UDSVERTN',
#  'UDSVERTE',
#  'UDSVERTI',
#  'MOCATOTS',
#  'CRAFTVRS',
#  'CRAFTURS',
#  'DIGFORCT',
#  'DIGFORSL',
#  'DIGBACCT',
#  'DIGBACLS',
#  'CRAFTDVR',
#  'CRAFTDRE',
#  'CRAFTDTI',
#  'CRAFTCUE-4',
#  'CRAFTCUE0',
#  'CRAFTCUE1',
#  'MINTTOTS',
#  'MINTTOTW',
#  'MINTSCNG',
#  'MINTSCNC',
#  'MINTPCNG',
#  'MINTPCNC',
#  'NACCAGEB',
#  'NACCNIHR-4',
#  'NACCNIHR1',
#  'NACCNIHR2',
#  'NACCNIHR3',
#  'NACCNIHR4',
#  'NACCNIHR5',
#  'NACCNIHR6',
#  'NACCAGE',
#  'NACCAAAS-4',
#  'NACCAAAS0',
#  'NACCAAAS1',
#  'NACCAANX-4',
#  'NACCAANX0',
#  'NACCAANX1',
#  'NACCAC-4',
#  'NACCAC0',
#  'NACCAC1',
#  'NACCACEI-4',
#  'NACCACEI0',
#  'NACCACEI1',
#  'NACCADEP-4',
#  'NACCADEP0',
#  'NACCADEP1',
#  'NACCAHTN-4',
#  'NACCAHTN0',
#  'NACCAHTN1',
#  'NACCAMD',
#  'NACCANGI-4',
#  'NACCANGI0',
#  'NACCANGI1',
#  'NACCAPSY-4',
#  'NACCAPSY0',
#  'NACCAPSY1',
#  'NACCBETA-4',
#  'NACCBETA0',
#  'NACCBETA1',
#  'NACCCCBS-4',
#  'NACCCCBS0',
#  'NACCCCBS1',
#  'NACCDBMD-4',
#  'NACCDBMD0',
#  'NACCDBMD1',
#  'NACCDIUR-4',
#  'NACCDIUR0',
#  'NACCDIUR1',
#  'NACCEMD-4',
#  'NACCEMD0',
#  'NACCEMD1',
#  'NACCEPMD-4',
#  'NACCEPMD0',
#  'NACCEPMD1',
#  'NACCHTNC-4',
#  'NACCHTNC0',
#  'NACCHTNC1',
#  'NACCLIPL-4',
#  'NACCLIPL0',
#  'NACCLIPL1',
#  'NACCNSD-4',
#  'NACCNSD0',
#  'NACCNSD1',
#  'NACCVASD-4',
#  'NACCVASD0',
#  'NACCVASD1',
#  'NACCBMI',
#  'NACCNE4S-4',
#  'NACCNE4S0',
#  'NACCNE4S1',
#  'NACCNE4S2',
#  'NACCAPOE-4',
#  'NACCAPOE1',
#  'NACCAPOE2',
#  'NACCAPOE3',
#  'NACCAPOE4',
#  'NACCAPOE5',
#  'NACCAPOE6',
#  'CSFABETA',
#  'CSFPTAU',
#  'CSFTTAU',
#  'CSFABMD-4',
#  'CSFABMD1',
#  'CSFABMD2',
#  'CSFPTMD-4.0',
#  'CSFPTMD1.0',
#  'CSFPTMD2.0',
#  'CSFTTMD-4.0',
#  'CSFTTMD1.0',
#  'CSFTTMD2.0']

# %%
lr_weights.shape
# Out:
# (4, 557)

# %%
wll_arr = np.array([[4,5,8],[7,2,0]])
np.argsort(wll_arr, axis=1)
# Out:
# array([[0, 1, 2],
#        [2, 1, 0]])

# %%
# sort the linear regression weights for each label to see which feature is more important for each label
# NOTE that the order is ascending, so if we want to get the most important ones, we need to reverse it
sort_perm_index = np.argsort(lr_weights, axis=1)

# %%
sort_perm_index
# Out:
# array([[420, 367, 423, ..., 439,   1, 477],
#        [  1, 293, 356, ..., 440, 483, 292],
#        [420, 367, 533, ..., 477,  20, 278],
#        [278, 333, 496, ..., 420, 535, 439]])

# %%
# sort weights for each disease and use the descending order
pure_alz_index_descending = sort_perm_index[0][::-1]
pure_lbd_index_descending = sort_perm_index[1][::-1]
mix_index_descending = sort_perm_index[2][::-1]
others_index_descending = sort_perm_index[3][::-1]

# %%
# transfer the name list into a numpy array and resort it according to the sort_perm_index
whole_feature_names_array = np.array(whole_feature_names_list)
# for label 0 (PURE AD)
pure_alz_feature_names_importance = whole_feature_names_array[pure_alz_index_descending]
# for label 1 (PURE LBD)
pure_lbd_feature_names_importance = whole_feature_names_array[pure_lbd_index_descending]
# for label 3 (MIX)
mix_feature_names_importance = whole_feature_names_array[mix_index_descending]
# for label 4 (OTHERS)
others_feature_names_importance = whole_feature_names_array[others_index_descending]

# %%
pure_alz_feature_names_importance
# Out:
# array(['NACCAGE', 'SEX2', 'WAIS', 'UDSVERLC', 'CSFPTAU', 'NITE0', 'HALL0',
#        'NACCADEP0', 'NACCAPOE2', 'NACCNE4S1', 'UDSVERTI', 'NACCFAM1',
#        'UDSVERLN', 'NITESEV-4', 'UDSVERFC', 'UDSBENTC', 'HALLSEV-4',
#        'TRAVEL0', 'GAMES0', 'NACCAGEB', 'UDSVERTN', 'BILLS0', 'CSFTTAU',
#        'DIGIB', 'TAXES0', 'MEALPREP0', 'TRAUMBRF-4', 'UDSVERNF',
#        'APASEV-4', 'TRAUMEXT-4', 'HYPERTEN2', 'IRR1', 'ANX0', 'SHOPPING0',
#        'APPSEV-4', 'TRAUMCHR-4', 'APNEA0', 'NACCCCBS1', 'APA0',
#        'MOCATOTS', 'ANXSEV-4', 'NACCAANX0', 'DIGBACCT', 'UDSBENRS1',
#        'MINTPCNG', 'TRAILBRR', 'IRRSEV1', 'TRAILARR', 'NPIQINF2', 'RBD0',
#        'UDSVERLR', 'ANIMALS', 'CVPACE-4', 'NACCAHTN1', 'CRAFTDVR',
#        'DIGIBLEN', 'GAMES-4', 'HISPANIC1', 'NACCAPSY0', 'MINTSCNG',
#        'NACCBMI', 'INCONTU0', 'NACCNINR2', 'NACCLIPL1', 'NACCNIHR2',
#        'APP0', 'NACCACEI1', 'PACKSPER1', 'CVAFIB0', 'NPIQINF3',
#        'TBIBRIEF0', 'NCOTHR-4', 'OTHSLEEP0', 'DEP2YRS0', 'DISN1',
#        'EVENTS0', 'BILLS1', 'STOVE0', 'MEALPREP2', 'DEPOTHR0', 'DIGBACLS',
#        'TOBAC300', 'CBSTROKE0', 'CVANGIO0', 'CVPACDEF0', 'HYPERTEN1',
#        'NACCNSD1', 'ARTHUNK0', 'HYPERCHO2', 'EVENTS3', 'CVOTHR0',
#        'IRRSEV2', 'CVHATT0', 'PSYCDIS0', 'ALCOHOL0', 'TRAILALI',
#        'INCONTF0', 'DEL0', 'B12DEF0', 'MINTSCNC', 'MOT1', 'INRELTO2',
#        'CRAFTCUE-4', 'DELSEV-4', 'DEPDSEV-4', 'CRAFTURS', 'INSEX1',
#        'THYROID1', 'DIGFORSL', 'DIABETES0', 'CVHVALVE0', 'REMDATES2',
#        'IRRSEV3', 'DISNSEV3', 'NACCBETA1', 'CRAFTVRS', 'PAYATTN-4',
#        'PAYATTN0', 'ELATSEV-4', 'NITE-4', 'HYPERCHO1', 'DISNSEV-4',
#        'B12DEF1', 'CVCHF0', 'NPSYDEV0', 'NACCHTNC0', 'OCD0', 'NACCTBI-4',
#        'PTSD0', 'HISPOR1', 'AGITSEV3', 'BIPOLAR0', 'ABUSOTHR0', 'SCHIZ0',
#        'EVENTS-4', 'THYROID0', 'ELAT0', 'ALCOCCAS1', 'HATTMULT-4',
#        'CSFTTMD2.0', 'MOTSEV2', 'STROKMUL-4', 'AGIT-4', 'TAXES-4',
#        'HALL-4', 'ELAT1', 'CSFTTMD-4.0', 'ARTHSPIN0', 'DEPD0', 'INSOMN0',
#        'DEL1', 'ALCFREQ-4', 'ARTHLOEX0', 'AGITSEV2', 'NACCNINR-4',
#        'TBIWOLOS0', 'TBIEXTEN0', 'DIABTYPE-4', 'APP-4', 'BPDIAS',
#        'PRIMLANG1', 'ARTHUPEX0', 'TOBAC1000', 'NACCAAAS0', 'DELSEV2',
#        'DEP2YRS1', 'THYROID2', 'CSFPTMD-4.0', 'NACCAPOE4', 'UDSBENRS0',
#        'ANYMEDS0', 'NACCDIUR0', 'DISN-4', 'NACCLIPL0', 'NACCNE4S2',
#        'DISN0', 'NITESEV3', 'DEPDSEV1', 'NCOTHR2', 'CSFABMD-4', 'NACCAC1',
#        'ALCFREQ4', 'PRIMLANG2', 'DEPD-4', 'STOVE2', 'PAYATTN1',
#        'TIAMULT-4', 'NACCAPOE5', 'ELAT-4', 'BIPOLAR-4', 'SHOPPING2',
#        'SCHIZ-4', 'OCD-4', 'PSYCDIS1', 'NACCDBMD1', 'PTSD-4', 'DISNSEV1',
#        'ARTHTYPE-4', 'NPSYDEV-4', 'CVHVALVE-4', 'NACCNIHR1', 'NACCEMD0',
#        'PACKSPER0', 'CBTIA0', 'TBIWOLOS-4', 'ALCOCCAS-4', 'ARTHRIT-4',
#        'RBD-4', 'ARTHSPIN-4', 'ARTHTYPE2', 'MOT0', 'TBI-4', 'ARTHLOEX-4',
#        'CVANGINA-4', 'IRR-4', 'AGITSEV-4', 'TBIEXTEN-4', 'TOBAC1001',
#        'REMDATES0', 'ARTHUPEX-4', 'ARTHUNK-4', 'NACCEPMD0', 'CVPACDEF-4',
#        'APA-4', 'ANXIETY-4', 'INSOMN-4', 'TBIBRIEF-4', 'APNEA-4',
#        'OTHSLEEP-4', 'DIGFORCT', 'MOT-4', 'ANXIETY0', 'ARTHRIT0', 'AGIT1',
#        'NACCANGI0', 'ELATSEV1', 'BILLS2', 'DEPOTHR1', 'INRELTO6', 'DEPD1',
#        'QUITSMOK', 'BILLS-4', 'HISPOR3', 'AGIT0', 'ANYMEDS1', 'STOVE1',
#        'TRAVEL-4', 'INCONTU2', 'MOTSEV-4', 'NACCTBI0', 'ARTHRIT1',
#        'CVBYPASS0', 'NACCVASD0', 'ALCOCCAS0', 'CSFPTMD2.0', 'CVANGIO1',
#        'NACCNINR3', 'REMDATES1', 'NACCHTNC1', 'NACCBETA0', 'TBI0',
#        'INRELTO7', 'NACCAC0', 'ANX-4', 'CVHATT2', 'DEL-4', 'APASEV3',
#        'PRIMLANG4', 'TRAUMCHR1', 'NACCAPOE3', 'PRIMLANG3', 'DIABTYPE2',
#        'MINTPCNC', 'NACCDBMD0', 'NACCFAM-4', 'CVBYPASS2', 'TRAUMBRF2',
#        'DELSEV3', 'MEALPREP1', 'NPIQINF-4', 'PRIMLANG5', 'HISPOR2',
#        'ALCFREQ2', 'HYPERCHO0', 'TAXES1', 'TRAUMCHR2', 'HISPANIC-4',
#        'CSFABMD2', 'CVOTHR1', 'APASEV2', 'NACCTBI1', 'EVENTS1',
#        'REMDATES-4', 'B12DEF2', 'ANXIETY1', 'CBTIA2', 'CVBYPASS1',
#        'NACCAHTN0', 'ARTHUPEX1', 'NACCNINR1', 'NPSYDEV2', 'ABUSOTHR2',
#        'APPSEV3', 'NACCACEI0', 'HISPOR-4', 'DIABETES1', 'INRELTO-4',
#        'TRAUMEXT2', 'ALCOHOL2', 'CVANGINA0', 'STOVE3', 'DELSEV1',
#        'CBTIA1', 'HALLSEV3', 'ALCFREQ0', 'CSFTTMD1.0', 'NACCBETA-4',
#        'HISPOR6', 'SHOPPING-4', 'HISPOR50', 'APPSEV1', 'STROKMUL1',
#        'ARTHTYPE3', 'TBIEXTEN1', 'INSEX-4', 'SEIZURES2', 'ARTHSPIN1',
#        'RBD1', 'CVPACDEF1', 'ALCFREQ3', 'NPSYDEV1', 'MOTSEV1', 'HISPOR5',
#        'STROKMUL0', 'PTSD1', 'CSFPTMD1.0', 'INSOMN2', 'INSOMN1',
#        'ARTHRIT2', 'DIABETES2', 'CVHVALVE1', 'CVAFIB1', 'BIPOLAR2',
#        'OCD1', 'CVANGINA2', 'HATTMULT1', 'DIABTYPE1', 'ARTHTYPE1',
#        'TBIBRIEF2', 'TBIWOLOS2', 'NACCNIHR4', 'TBIWOLOS1', 'TRAUMBRF1',
#        'OTHSLEEP2', 'CVHVALVE2', 'SEIZURES0', 'ELATSEV3', 'NACCNINR4',
#        'TRAUMEXT1', 'SCHIZ2', 'NACCVASD1', 'DIABTYPE3', 'OCD2',
#        'NACCNIHR3', 'ALCFREQ1', 'MOTSEV3', 'TBIBRIEF1', 'PRIMLANG6',
#        'ABUSOTHR1', 'TBIEXTEN2', 'HATTMULT0', 'ELATSEV2', 'SMOKYRS',
#        'ARTHUNK1', 'CRAFTCUE0', 'CVPACDEF2', 'NACCEPMD1', 'ARTHLOEX1',
#        'CSFABMD1', 'TOBAC301', 'RBD2', 'ALCOHOL1', 'TIAMULT0', 'PTSD2',
#        'CVHATT1', 'NACCNIHR-4', 'TBI1', 'APNEA1', 'CVANGIO2', 'NACCAPOE6',
#        'AGITSEV1', 'TIAMULT1', 'STOVE-4', 'NACCCCBS0', 'ANXIETY2',
#        'APNEA2', 'OTHSLEEP1', 'PACKSPER4', 'SCHIZ1', 'NACCANGI1',
#        'CVPACE2', 'CBSTROKE1', 'HISPOR4', 'HISPANIC0', 'BIPOLAR1', 'VEG',
#        'DISNSEV2', 'NCOTHR1', 'CVANGINA1', 'PSYCDIS2', 'NACCNINR6',
#        'SEIZURES1', 'NACCNIHR6', 'PRIMLANG-4', 'BPSYS', 'NACCAC-4',
#        'NITESEV1', 'CVOTHR2', 'INRELTO3', 'NACCAPSY1', 'INCONTF2',
#        'NACCDIUR1', 'CVPACE1', 'IRRSEV-4', 'CVCHF2', 'CBTIA-4', 'CVCHF1',
#        'CBSTROKE2', 'TBI2', 'INRELTO5', 'NACCNSD0', 'SHOPPING1',
#        'NACCLIPL-4', 'CRAFTDTI', 'NACCAHTN-4', 'ANYMEDS-4', 'UDSBENRS-4',
#        'NACCEMD-4', 'NACCAPSY-4', 'NACCAANX1', 'REMDATES3', 'INSEX2',
#        'NACCNSD-4', 'NACCAAAS-4', 'NACCHTNC-4', 'NACCEPMD-4', 'TRAVEL1',
#        'EVENTS2', 'NACCACEI-4', 'NACCEMD1', 'NACCVASD-4', 'NACCAPOE-4',
#        'PAYATTN2', 'NACCAANX-4', 'NACCAAAS1', 'NACCANGI-4', 'NACCCCBS-4',
#        'NACCDIUR-4', 'NACCADEP-4', 'ANXSEV2', 'TAXES3', 'TAXES2',
#        'PAYATTN3', 'NACCDBMD-4', 'PACKSPER3', 'PACKSPER5', 'ANXSEV1',
#        'NACCNE4S-4', 'PACKSPER2', 'GAMES2', 'DEPDSEV3', 'DIGIFLEN',
#        'NACCAPOE1', 'INRELTO4', 'NCOTHR0', 'TRAVEL2', 'IRR0', 'TRAUMBRF0',
#        'TRAUMEXT0', 'INCONTF1', 'TOBAC30-4', 'INCONTU1', 'MEALPREP-4',
#        'DIABETES-4', 'INCONTF-4', 'ANXSEV3', 'NITESEV2', 'INRELTO1',
#        'TRAUMCHR0', 'UDSVERTE', 'INCONTU-4', 'CVAFIB2', 'B12DEF-4',
#        'APASEV1', 'CBSTROKE-4', 'CVANGIO-4', 'DEPDSEV2', 'UDSVERFN',
#        'PACKSPER-4', 'HYPERTEN-4', 'CVHATT-4', 'CVBYPASS-4', 'APP1',
#        'SEIZURES-4', 'THYROID-4', 'HALLSEV2', 'ABUSOTHR-4', 'CVOTHR-4',
#        'CVCHF-4', 'DEPOTHR-4', 'ALCOHOL-4', 'LOGIMEM', 'CSFABETA',
#        'PSYCDIS-4', 'HYPERCHO-4', 'DEP2YRS-4', 'NPIQINF1', 'BILLS3',
#        'TOBAC100-4', 'CVAFIB-4', 'MEALPREP3', 'DIGIF', 'APA1', 'CVPACE0',
#        'GAMES3', 'MINTTOTS', 'APPSEV2', 'HYPERTEN0', 'NACCNIHR5', 'EDUC',
#        'ANX1', 'MINTTOTW', 'NACCNE4S0', 'NACCNINR5', 'INEDUC', 'CDRSUM',
#        'HALLSEV1', 'GAMES1', 'CRAFTCUE1', 'TRAVEL3', 'SHOPPING3',
#        'NACCADEP1', 'NACCFAM0', 'NACCAMD', 'TRAILBLI', 'BOSTON', 'NITE1',
#        'HALL1', 'SEX1', 'TRAILB', 'MEMTIME', 'NACCMMSE', 'TRAILA',
#        'CRAFTDRE', 'UDSBENTD', 'NACCGDS', 'MEMUNITS'], dtype='<U11')

# %%
pure_lbd_feature_names_importance
# Out:
# array(['HALL1', 'NACCAANX1', 'BOSTON', 'NACCMMSE', 'TRAILA', 'NITE1',
#        'SEX1', 'INRELTO1', 'TRAILB', 'MEMUNITS', 'NACCNE4S-4',
#        'NACCAPOE-4', 'NACCGDS', 'NPIQINF1', 'NACCAMD', 'MINTTOTW',
#        'MEMTIME', 'MOCATOTS', 'TRAILALI', 'ANIMALS', 'EDUC', 'NACCLIPL0',
#        'UDSVERTN', 'DISN0', 'NACCNINR1', 'MINTTOTS', 'UDSVERFC', 'GAMES1',
#        'UDSVERFN', 'NACCACEI0', 'INEDUC', 'DISNSEV-4', 'CRAFTDRE',
#        'UDSVERLC', 'NACCANGI1', 'UDSBENTD', 'MEALPREP-4', 'DIGFORCT',
#        'TRAVEL1', 'LOGIMEM', 'HALLSEV2', 'INCONTU1', 'CVPACE1',
#        'DIABETES0', 'NACCDIUR0', 'CRAFTURS', 'HALLSEV1', 'TRAVEL3',
#        'CBSTROKE0', 'NACCNIHR5', 'BILLS3', 'CVCHF1', 'TAXES3', 'MINTPCNC',
#        'NACCDBMD0', 'CVBYPASS2', 'TRAILBLI', 'VEG', 'UDSVERTE',
#        'PAYATTN1', 'CRAFTDTI', 'CRAFTDVR', 'INSEX2', 'TRAILARR',
#        'INRELTO4', 'DELSEV2', 'PSYCDIS2', 'PACKSPER5', 'NACCNINR5',
#        'NACCNIHR1', 'CVANGIO1', 'RBD1', 'ALCOCCAS0', 'CVOTHR2',
#        'NACCBETA0', 'APP0', 'APASEV1', 'PAYATTN3', 'ARTHRIT1', 'AGIT0',
#        'DIGFORSL', 'ARTHTYPE2', 'DIGBACCT', 'INSOMN1', 'ANXIETY1',
#        'DEPDSEV3', 'NACCTBI1', 'ARTHUPEX1', 'SEIZURES2', 'ANXSEV2',
#        'TBI0', 'NACCAHTN0', 'GAMES3', 'PTSD0', 'APPSEV2', 'CVPACDEF0',
#        'CRAFTVRS', 'ARTHLOEX0', 'NPSYDEV0', 'DIGIBLEN', 'CVHVALVE0',
#        'ARTHUNK0', 'CVAFIB1', 'APA1', 'CSFPTAU', 'SCHIZ0', 'OTHSLEEP0',
#        'OCD0', 'SHOPPING-4', 'UDSBENTC', 'ALCFREQ4', 'TBIWOLOS0',
#        'HISPANIC0', 'TBIEXTEN0', 'TBIBRIEF0', 'DEP2YRS0', 'CVANGINA0',
#        'APASEV2', 'ARTHSPIN0', 'BIPOLAR0', 'IRR0', 'CSFTTAU', 'REMDATES1',
#        'DEL1', 'EVENTS0', 'TRAUMBRF2', 'HISPOR-4', 'APNEA0', 'STOVE2',
#        'NACCADEP0', 'CVHATT2', 'SHOPPING3', 'APPSEV-4', 'DEPD0',
#        'TBIEXTEN2', 'STOVE3', 'THYROID1', 'NACCNINR6', 'CVHATT1',
#        'INSEX-4', 'DEPOTHR1', 'HYPERTEN0', 'APNEA1', 'ALCFREQ0',
#        'TBIEXTEN1', 'CVBYPASS1', 'ABUSOTHR2', 'MEALPREP2', 'TBI2',
#        'ARTHTYPE1', 'INRELTO-4', 'NACCAPOE5', 'TBIBRIEF1', 'INCONTF2',
#        'PSYCDIS1', 'PACKSPER3', 'CVOTHR1', 'ANXSEV3', 'OTHSLEEP2',
#        'CVOTHR0', 'ARTHSPIN1', 'PRIMLANG5', 'INRELTO7', 'CVHVALVE1',
#        'INRELTO2', 'TRAUMBRF1', 'NACCNINR4', 'STROKMUL0', 'NACCNIHR3',
#        'SHOPPING1', 'PAYATTN-4', 'PRIMLANG-4', 'CRAFTCUE1', 'ALCFREQ2',
#        'NITESEV3', 'PTSD2', 'NACCAPSY-4', 'ELATSEV2', 'NACCVASD-4',
#        'PRIMLANG4', 'NITESEV2', 'TRAUMEXT1', 'SHOPPING2', 'HISPOR50',
#        'TBIWOLOS1', 'TBIWOLOS2', 'CVCHF2', 'NACCEMD-4', 'DIABTYPE2',
#        'NACCNSD-4', 'OCD2', 'NACCEPMD-4', 'NACCLIPL-4', 'HISPANIC-4',
#        'NACCVASD1', 'DIABTYPE3', 'EVENTS3', 'DEPDSEV-4', 'NACCAAAS-4',
#        'STROKMUL1', 'APASEV3', 'INRELTO3', 'RBD0', 'B12DEF2', 'AGITSEV-4',
#        'HISPOR4', 'UDSBENRS-4', 'ARTHTYPE3', 'NPSYDEV1', 'ARTHUPEX0',
#        'TIAMULT0', 'NACCBETA-4', 'EVENTS-4', 'NACCADEP-4', 'STOVE-4',
#        'OTHSLEEP1', 'NACCCCBS-4', 'HATTMULT0', 'CVHVALVE2', 'NACCAC0',
#        'INCONTU2', 'ARTHRIT0', 'PRIMLANG3', 'NACCEMD1', 'SCHIZ1',
#        'TAXES1', 'HISPOR1', 'NACCNIHR4', 'THYROID0', 'HISPOR3',
#        'BIPOLAR2', 'NACCNINR3', 'NACCANGI-4', 'CVPACDEF1', 'NACCNINR-4',
#        'SEIZURES0', 'CSFPTMD1.0', 'NACCDBMD-4', 'TRAUMCHR2', 'TRAVEL-4',
#        'NACCNIHR6', 'HISPOR2', 'ALCFREQ3', 'BIPOLAR1', 'NACCHTNC-4',
#        'DISNSEV3', 'DIABTYPE1', 'OCD1', 'NPSYDEV2', 'PRIMLANG6',
#        'MOTSEV3', 'INSOMN2', 'APNEA2', 'RBD2', 'ELAT1', 'ALCOHOL1',
#        'ANYMEDS-4', 'TIAMULT1', 'ELATSEV3', 'NCOTHR2', 'PACKSPER4',
#        'ALCFREQ1', 'PTSD1', 'ARTHUNK1', 'ABUSOTHR1', 'NACCAC-4',
#        'ANYMEDS0', 'NACCAPOE6', 'IRRSEV2', 'B12DEF1', 'HISPOR6',
#        'NACCACEI-4', 'CBSTROKE1', 'ARTHRIT2', 'NACCDIUR-4', 'APPSEV3',
#        'NACCEPMD1', 'ANXIETY2', 'SCHIZ2', 'ELATSEV1', 'THYROID2',
#        'SEIZURES1', 'TBIBRIEF2', 'NACCAANX-4', 'HATTMULT1', 'HALLSEV3',
#        'TOBAC301', 'CVPACDEF2', 'CVANGINA2', 'REMDATES2', 'TOBAC300',
#        'IRRSEV3', 'NACCAHTN-4', 'DIABETES2', 'DEPDSEV1', 'NACCAAAS1',
#        'INCONTF0', 'CVPACE2', 'CBTIA0', 'NACCNIHR-4', 'CSFTTMD1.0',
#        'STOVE1', 'BILLS1', 'CVANGINA1', 'ARTHLOEX1', 'NACCHTNC0',
#        'IRRSEV-4', 'APP1', 'CBTIA1', 'MOT0', 'NACCFAM0', 'DELSEV3',
#        'ALCOHOL2', 'NACCFAM-4', 'UDSBENRS0', 'ELAT0', 'CSFABMD1',
#        'DELSEV1', 'B12DEF0', 'CVAFIB2', 'NACCFAM1', 'ANX-4', 'ANX1',
#        'TBI1', 'TRAUMCHR0', 'CSFPTMD2.0', 'DISNSEV2', 'TRAUMEXT0',
#        'MOT-4', 'ANXIETY0', 'INRELTO6', 'CSFABMD2', 'CSFTTMD2.0',
#        'TRAUMCHR1', 'REMDATES-4', 'CVAFIB0', 'NACCNE4S0', 'INSOMN0',
#        'DEPD-4', 'EVENTS1', 'NACCAPOE3', 'APP-4', 'NCOTHR1', 'ABUSOTHR0',
#        'AGITSEV3', 'MEALPREP3', 'ALCOCCAS1', 'MOTSEV1', 'NCOTHR0',
#        'MINTSCNC', 'TRAUMBRF0', 'NACCAPSY1', 'HYPERCHO0', 'DEL0',
#        'TRAUMEXT2', 'ALCOHOL0', 'NACCAAAS0', 'PACKSPER2', 'PRIMLANG2',
#        'IRR-4', 'DEL-4', 'NITE-4', 'NPIQINF-4', 'DISN-4', 'NACCNINR2',
#        'PRIMLANG1', 'HALL-4', 'CSFTTMD-4.0', 'CVHATT0', 'CRAFTCUE-4',
#        'NACCNSD0', 'CSFABMD-4', 'NACCAPOE4', 'CVANGIO2', 'MOTSEV-4',
#        'CBSTROKE2', 'TOBAC1001', 'ELAT-4', 'HISPOR5', 'INRELTO5',
#        'CSFPTMD-4.0', 'GAMES-4', 'NACCCCBS1', 'PACKSPER0', 'NACCNE4S2',
#        'AGIT-4', 'DEPOTHR0', 'DIGBACLS', 'APA-4', 'NACCAPOE1',
#        'TOBAC1000', 'NACCADEP1', 'REMDATES0', 'NPIQINF3', 'NACCNSD1',
#        'TRAVEL2', 'NACCNIHR2', 'NACCCCBS0', 'NACCEMD0', 'UDSVERTI',
#        'ANYMEDS1', 'ELATSEV-4', 'PAYATTN2', 'PSYCDIS0', 'DELSEV-4',
#        'TAXES-4', 'NACCVASD0', 'BILLS-4', 'NACCHTNC1', 'TAXES2',
#        'CVBYPASS0', 'HISPANIC1', 'INCONTF1', 'HYPERCHO2', 'CVANGIO0',
#        'NACCEPMD0', 'QUITSMOK', 'CRAFTCUE0', 'APA0', 'DIABTYPE-4',
#        'EVENTS2', 'HATTMULT-4', 'SHOPPING0', 'REMDATES3', 'TIAMULT-4',
#        'MEALPREP0', 'AGITSEV2', 'B12DEF-4', 'NPIQINF2', 'CVCHF0',
#        'STROKMUL-4', 'UDSVERLN', 'INSOMN-4', 'ANXIETY-4', 'CVPACDEF-4',
#        'ARTHTYPE-4', 'OCD-4', 'APNEA-4', 'TBI-4', 'ALCFREQ-4',
#        'TBIEXTEN-4', 'ARTHSPIN-4', 'NPSYDEV-4', 'IRRSEV1', 'OTHSLEEP-4',
#        'TBIBRIEF-4', 'ARTHRIT-4', 'TBIWOLOS-4', 'RBD-4', 'ARTHUNK-4',
#        'ARTHUPEX-4', 'BIPOLAR-4', 'SCHIZ-4', 'NACCTBI0', 'CVANGINA-4',
#        'ALCOCCAS-4', 'ARTHLOEX-4', 'DEP2YRS1', 'CVHVALVE-4', 'HYPERTEN2',
#        'MOT1', 'NITESEV1', 'MOTSEV2', 'CBTIA2', 'CSFABETA', 'PTSD-4',
#        'NACCAPSY0', 'TAXES0', 'ANXSEV-4', 'BILLS2', 'ANX0', 'HYPERTEN1',
#        'CVPACE-4', 'APASEV-4', 'TRAUMBRF-4', 'NCOTHR-4', 'TRAUMEXT-4',
#        'DIGIF', 'UDSBENRS1', 'NACCAC1', 'TRAUMCHR-4', 'DEPD1', 'PAYATTN0',
#        'ANXSEV1', 'CVBYPASS-4', 'CVANGIO-4', 'CVHATT-4', 'THYROID-4',
#        'SEIZURES-4', 'HYPERTEN-4', 'CBSTROKE-4', 'INCONTU-4', 'ALCOHOL-4',
#        'TOBAC30-4', 'NACCTBI-4', 'CVOTHR-4', 'ABUSOTHR-4', 'CVCHF-4',
#        'INCONTF-4', 'PACKSPER1', 'CBTIA-4', 'HYPERCHO-4', 'CVAFIB-4',
#        'STOVE0', 'DIABETES-4', 'PACKSPER-4', 'PSYCDIS-4', 'DEPDSEV2',
#        'APPSEV1', 'TOBAC100-4', 'CVPACE0', 'DEPOTHR-4', 'DIGIFLEN',
#        'IRR1', 'WAIS', 'DEP2YRS-4', 'AGITSEV1', 'DIGIB', 'NACCAHTN1',
#        'INSEX1', 'DIABETES1', 'GAMES2', 'AGIT1', 'UDSVERNF', 'DISNSEV1',
#        'TRAILBRR', 'MINTSCNG', 'NACCDBMD1', 'BILLS0', 'NACCANGI0',
#        'INCONTU0', 'NACCBETA1', 'MEALPREP1', 'MINTPCNG', 'UDSVERLR',
#        'GAMES0', 'NACCBMI', 'HYPERCHO1', 'BPDIAS', 'NACCAGEB',
#        'NACCLIPL1', 'NACCDIUR1', 'TRAVEL0', 'DISN1', 'NACCACEI1',
#        'SMOKYRS', 'NACCAPOE2', 'NACCAGE', 'BPSYS', 'NACCNE4S1', 'NITE0',
#        'CDRSUM', 'HALL0', 'NACCAANX0', 'NITESEV-4', 'HALLSEV-4', 'SEX2'],
#       dtype='<U11')

# %%
mix_feature_names_importance
# Out:
# array(['CDRSUM', 'EDUC', 'NACCAGE', 'BOSTON', 'NACCAGEB', 'DIGIF',
#        'HYPERCHO1', 'TRAILA', 'TRAILB', 'HALL1', 'HALLSEV1', 'HYPERTEN0',
#        'REMDATES3', 'DELSEV1', 'CVPACE0', 'NCOTHR0', 'DEPOTHR0',
#        'INCONTU0', 'ANXSEV3', 'DEL1', 'NITESEV1', 'NACCAHTN0', 'INEDUC',
#        'SEX1', 'INRELTO5', 'ANXSEV1', 'INSEX1', 'TRAUMBRF0', 'TAXES-4',
#        'TRAUMEXT0', 'NACCAPOE1', 'CVAFIB-4', 'NACCAANX0', 'NACCANGI0',
#        'BPSYS', 'NACCNE4S2', 'NACCAPOE4', 'NITE1', 'PACKSPER1', 'BILLS-4',
#        'TRAUMCHR0', 'CRAFTCUE1', 'UDSBENRS1', 'NACCFAM-4', 'MEALPREP-4',
#        'PACKSPER4', 'NACCTBI0', 'MINTTOTW', 'ALCOHOL0', 'CVCHF0',
#        'NACCCCBS0', 'MEALPREP1', 'MINTPCNG', 'STOVE0', 'HISPOR5',
#        'TRAUMCHR1', 'TRAVEL1', 'THYROID2', 'PRIMLANG4', 'PAYATTN2',
#        'CVANGIO0', 'CBSTROKE0', 'IRRSEV-4', 'NPIQINF1', 'BILLS3',
#        'NACCFAM0', 'TOBAC100-4', 'IRR0', 'ABUSOTHR-4', 'GAMES1',
#        'HYPERCHO2', 'DIGIFLEN', 'CVAFIB0', 'CVBYPASS0', 'NITESEV2',
#        'NPSYDEV-4', 'BIPOLAR-4', 'DIGBACLS', 'OCD-4', 'TBIWOLOS-4',
#        'CVANGINA-4', 'PTSD-4', 'CVHVALVE-4', 'TBI-4', 'OTHSLEEP-4',
#        'ANXIETY-4', 'RBD-4', 'TBIEXTEN-4', 'INSOMN-4', 'TRAVEL2',
#        'SCHIZ-4', 'CVPACDEF-4', 'APNEA-4', 'ALCOCCAS-4', 'TBIBRIEF-4',
#        'ARTHSPIN-4', 'ARTHUPEX-4', 'ARTHLOEX-4', 'ARTHRIT-4', 'ARTHUNK-4',
#        'IRR-4', 'NACCAPSY0', 'INRELTO1', 'NACCAAAS0', 'PRIMLANG2',
#        'ANX-4', 'CVBYPASS-4', 'CRAFTDTI', 'CVANGIO-4', 'NPIQINF3',
#        'PSYCDIS-4', 'APP-4', 'NACCAC1', 'SEIZURES0', 'APA-4', 'DEL-4',
#        'NITE-4', 'EVENTS2', 'CBTIA0', 'AGIT-4', 'NACCHTNC1', 'HALL-4',
#        'DEPDSEV1', 'AGITSEV3', 'EVENTS1', 'APASEV3', 'DEP2YRS-4',
#        'NACCDBMD0', 'NACCNSD1', 'NACCBETA0', 'UDSBENRS-4', 'MOTSEV-4',
#        'ANYMEDS0', 'PACKSPER0', 'APA0', 'NPIQINF-4', 'DISN-4',
#        'ALCFREQ-4', 'CSFPTMD2.0', 'TOBAC1000', 'ELAT-4', 'AGITSEV2',
#        'NACCVASD0', 'CVANGIO2', 'NACCNINR1', 'APASEV-4', 'DIABETES-4',
#        'TOBAC30-4', 'ANX1', 'CRAFTCUE-4', 'HALLSEV2', 'NACCEPMD0',
#        'STOVE-4', 'SHOPPING2', 'NACCNIHR1', 'ARTHTYPE-4', 'PSYCDIS0',
#        'MOT-4', 'HISPANIC1', 'HYPERTEN-4', 'AGIT1', 'DISN1', 'DEPD-4',
#        'CVCHF-4', 'NACCACEI0', 'INCONTF-4', 'TRAUMBRF2', 'ELATSEV-4',
#        'NACCEMD0', 'DEPD1', 'MINTSCNG', 'NACCDIUR1', 'NACCNIHR2',
#        'STROKMUL-4', 'DIABTYPE-4', 'CSFABMD2', 'NACCDIUR0', 'SHOPPING1',
#        'SEIZURES-4', 'HATTMULT-4', 'MINTTOTS', 'ANYMEDS1', 'APP1',
#        'NACCHTNC0', 'TIAMULT-4', 'DEP2YRS1', 'MEALPREP3', 'ELAT0',
#        'CVHATT-4', 'CSFTTMD2.0', 'NACCEMD-4', 'SHOPPING3', 'INCONTU2',
#        'NACCNINR5', 'HISPANIC0', 'NACCEPMD1', 'DISNSEV1', 'NACCEMD1',
#        'INCONTF0', 'TAXES3', 'NACCNINR2', 'ARTHTYPE1', 'HATTMULT1',
#        'CVOTHR2', 'HISPOR-4', 'HISPOR2', 'TOBAC301', 'CBTIA1',
#        'TBIBRIEF1', 'SEIZURES1', 'NACCNIHR6', 'PRIMLANG1', 'NACCNIHR5',
#        'TRAVEL3', 'PRIMLANG6', 'RBD2', 'NCOTHR1', 'ARTHUNK1', 'OCD1',
#        'CSFPTMD1.0', 'CVOTHR1', 'CVANGINA2', 'MOTSEV3', 'NACCNIHR3',
#        'ALCFREQ2', 'AGITSEV-4', 'ABUSOTHR0', 'CSFABMD1', 'CSFTTMD1.0',
#        'CVCHF2', 'PRIMLANG3', 'ALCFREQ3', 'INRELTO4', 'INRELTO3',
#        'ARTHTYPE3', 'NACCNIHR4', 'PRIMLANG5', 'APPSEV1', 'ARTHRIT0',
#        'ARTHLOEX1', 'CVBYPASS1', 'OCD2', 'TIAMULT1', 'TRAUMBRF1',
#        'ALCOCCAS1', 'HISPANIC-4', 'ARTHRIT2', 'SCHIZ1', 'TBIWOLOS1',
#        'NACCNIHR-4', 'SEIZURES2', 'INRELTO-4', 'NACCAAAS-4', 'HISPOR6',
#        'NACCDIUR-4', 'NACCBETA-4', 'NACCAPOE6', 'NPSYDEV2', 'ALCOHOL1',
#        'ALCOHOL-4', 'NACCNSD-4', 'HISPOR3', 'INRELTO6', 'PRIMLANG-4',
#        'NACCNINR3', 'IRRSEV1', 'APNEA1', 'ANXIETY0', 'NACCLIPL-4',
#        'NACCNINR-4', 'CVHATT1', 'OTHSLEEP2', 'DIABETES0', 'ALCFREQ1',
#        'HISPOR4', 'TBIEXTEN2', 'ELATSEV1', 'ALCFREQ0', 'APPSEV2',
#        'TIAMULT0', 'DIABTYPE3', 'SCHIZ2', 'MOT0', 'CVHVALVE1', 'AGIT0',
#        'DIABTYPE1', 'BIPOLAR1', 'CVPACDEF2', 'NACCDBMD-4', 'HISPOR1',
#        'NACCHTNC-4', 'NACCAC-4', 'NACCADEP-4', 'PTSD2', 'NACCAANX-4',
#        'NACCCCBS-4', 'TBIEXTEN1', 'NACCVASD-4', 'NACCVASD1', 'CVHVALVE2',
#        'ABUSOTHR2', 'TBIBRIEF2', 'OTHSLEEP1', 'ALCFREQ4', 'NACCAHTN-4',
#        'TRAUMCHR2', 'BIPOLAR2', 'MEALPREP2', 'CVANGINA1', 'NACCANGI-4',
#        'NACCAPSY-4', 'TAXES1', 'TRAUMEXT1', 'ARTHSPIN1', 'NPSYDEV1',
#        'INCONTF2', 'APNEA2', 'NACCACEI-4', 'NACCEPMD-4', 'NACCNINR4',
#        'DEPDSEV2', 'ARTHUPEX0', 'TBI1', 'INSOMN0', 'PSYCDIS2', 'NITESEV3',
#        'DIABTYPE2', 'ANXIETY2', 'HISPOR50', 'CVPACE2', 'TBIWOLOS2',
#        'ANYMEDS-4', 'ELATSEV3', 'CVHATT0', 'INSOMN2', 'APPSEV3',
#        'ABUSOTHR1', 'TBI2', 'STROKMUL0', 'CVOTHR0', 'HATTMULT0', 'RBD0',
#        'AGITSEV1', 'CVOTHR-4', 'STROKMUL1', 'TOBAC300', 'INSEX-4',
#        'HYPERTEN2', 'UDSVERTE', 'CVAFIB1', 'NACCADEP0', 'PTSD1',
#        'REMDATES-4', 'CVPACDEF1', 'STOVE3', 'NACCNE4S1', 'MOTSEV2',
#        'TRAUMEXT2', 'B12DEF2', 'REMDATES1', 'IRRSEV3', 'NACCNINR6',
#        'DELSEV3', 'ARTHTYPE2', 'APASEV1', 'DEPDSEV-4', 'RBD1',
#        'PACKSPER-4', 'THYROID0', 'UDSBENRS0', 'ALCOHOL2', 'INCONTU-4',
#        'HALLSEV3', 'DEPD0', 'DIABETES2', 'CVHATT2', 'ANXIETY1',
#        'TRAILBLI', 'PTSD0', 'INRELTO2', 'CVPACDEF0', 'PSYCDIS1',
#        'B12DEF0', 'NACCAPOE2', 'MOTSEV1', 'GAMES-4', 'CBTIA2',
#        'CVANGINA0', 'CVHVALVE0', 'GAMES2', 'GAMES3', 'TBI0', 'HYPERCHO-4',
#        'B12DEF-4', 'DISNSEV2', 'ALCOCCAS0', 'ELATSEV2', 'DISNSEV3',
#        'MOT1', 'CVANGIO1', 'CBSTROKE1', 'NACCAPOE5', 'INCONTF1',
#        'DIGBACCT', 'TOBAC1001', 'NACCNE4S0', 'BILLS2', 'B12DEF1',
#        'INSOMN1', 'CRAFTCUE0', 'INRELTO7', 'DEP2YRS0', 'CBSTROKE-4',
#        'PAYATTN1', 'NACCTBI-4', 'NCOTHR2', 'ARTHRIT1', 'OCD0',
#        'TBIWOLOS0', 'ARTHSPIN0', 'TBIEXTEN0', 'NPSYDEV0', 'PAYATTN3',
#        'EVENTS-4', 'ELAT1', 'SCHIZ0', 'OTHSLEEP0', 'ARTHUPEX1', 'IRRSEV2',
#        'NACCACEI1', 'SHOPPING-4', 'UDSVERLR', 'ANXSEV-4', 'APA1',
#        'NACCAAAS1', 'THYROID-4', 'DIGIB', 'REMDATES2', 'IRR1',
#        'PACKSPER2', 'NPIQINF2', 'ARTHLOEX0', 'TRAVEL-4', 'ARTHUNK0',
#        'DIGIBLEN', 'BIPOLAR0', 'DEPDSEV3', 'PAYATTN-4', 'DELSEV2',
#        'TRAVEL0', 'PACKSPER5', 'INSEX2', 'CVAFIB2', 'ANX0', 'SHOPPING0',
#        'TBIBRIEF0', 'TRAILBRR', 'NACCLIPL1', 'BPDIAS', 'EVENTS3',
#        'MEMTIME', 'NACCTBI1', 'NACCAMD', 'DIGFORSL', 'NITESEV-4',
#        'TAXES2', 'DEPOTHR-4', 'CVCHF1', 'DIGFORCT', 'NITE0', 'CVPACE1',
#        'NACCADEP1', 'CVBYPASS2', 'DIABETES1', 'NACCAPSY1', 'CSFABMD-4',
#        'TRAILARR', 'UDSVERFN', 'CSFTTMD-4.0', 'APNEA0', 'NACCDBMD1',
#        'DISNSEV-4', 'PACKSPER3', 'CSFPTMD-4.0', 'DISN0', 'CBSTROKE2',
#        'BILLS0', 'BILLS1', 'DEPOTHR1', 'APP0', 'EVENTS0', 'NACCFAM1',
#        'PAYATTN0', 'APPSEV-4', 'THYROID1', 'STOVE2', 'STOVE1',
#        'NACCLIPL0', 'CSFTTAU', 'NACCAHTN1', 'DEL0', 'NACCBETA1',
#        'APASEV2', 'HALL0', 'CSFPTAU', 'DELSEV-4', 'CBTIA-4', 'HALLSEV-4',
#        'HYPERTEN1', 'CSFABETA', 'TRAILALI', 'NACCAC0', 'CRAFTDRE',
#        'LOGIMEM', 'CRAFTVRS', 'NACCNSD0', 'NACCCCBS1', 'CRAFTDVR',
#        'HYPERCHO0', 'QUITSMOK', 'NACCANGI1', 'UDSVERFC', 'NACCAANX1',
#        'UDSVERTN', 'TRAUMBRF-4', 'INCONTU1', 'SMOKYRS', 'TAXES0',
#        'MEALPREP0', 'REMDATES0', 'ANXSEV2', 'NACCAPOE3', 'UDSVERLC',
#        'ANIMALS', 'CVPACE-4', 'NACCMMSE', 'TRAUMCHR-4', 'WAIS',
#        'UDSVERNF', 'TRAUMEXT-4', 'NACCAPOE-4', 'NACCNE4S-4', 'NCOTHR-4',
#        'UDSBENTC', 'MINTSCNC', 'CRAFTURS', 'UDSVERTI', 'UDSBENTD',
#        'GAMES0', 'MOCATOTS', 'SEX2', 'UDSVERLN', 'MINTPCNC', 'VEG',
#        'NACCBMI', 'NACCGDS', 'MEMUNITS'], dtype='<U11')

# %%
others_feature_names_importance
# Out:
# array(['WAIS', 'NACCNE4S0', 'MEMUNITS', 'NACCBMI', 'UDSBENTD',
#        'REMDATES0', 'NACCMMSE', 'UDSBENTC', 'QUITSMOK', 'DISN1',
#        'NACCGDS', 'LOGIMEM', 'BILLS0', 'SMOKYRS', 'NACCDIUR1', 'TRAILALI',
#        'ANXSEV2', 'HYPERTEN1', 'NACCAHTN1', 'VEG', 'TAXES0', 'CBSTROKE2',
#        'NACCBETA1', 'TRAVEL0', 'NACCDBMD1', 'DEPDSEV2', 'MEMTIME',
#        'DIABETES1', 'BPDIAS', 'NACCAPSY1', 'NACCADEP1', 'GAMES2', 'MOT1',
#        'APASEV2', 'CSFABETA', 'MINTTOTW', 'APPSEV1', 'BILLS2', 'DISNSEV2',
#        'NACCAPOE3', 'APA1', 'INCONTF1', 'MOCATOTS', 'MEALPREP3',
#        'MEALPREP1', 'SHOPPING3', 'MINTPCNC', 'PACKSPER-4', 'HALLSEV-4',
#        'CRAFTVRS', 'NPIQINF3', 'NACCCCBS1', 'AGIT1', 'AGITSEV1',
#        'NACCAAAS1', 'CVAFIB2', 'THYROID1', 'HALL0', 'PACKSPER3', 'ELAT1',
#        'CBTIA2', 'SEX1', 'NACCAANX1', 'DIGIFLEN', 'TAXES2', 'NACCFAM0',
#        'PAYATTN2', 'NACCNSD0', 'MINTTOTS', 'UDSVERLC', 'NACCACEI1',
#        'CRAFTDRE', 'CRAFTDVR', 'NACCLIPL1', 'PACKSPER2', 'TRAVEL-4',
#        'STOVE1', 'GAMES0', 'ANX1', 'MOTSEV1', 'BILLS1', 'DEPOTHR1',
#        'APP1', 'CRAFTURS', 'TRAUMCHR1', 'UDSVERLR', 'GAMES3',
#        'NACCNE4S-4', 'TRAILBRR', 'IRR-4', 'NACCAPOE-4', 'APASEV1',
#        'MOTSEV2', 'UDSVERNF', 'ELATSEV1', 'HALLSEV2', 'B12DEF1', 'DEPD-4',
#        'ALCOHOL2', 'PAYATTN0', 'DISNSEV1', 'UDSVERTI', 'CVANGIO1',
#        'DEL-4', 'HALL-4', 'REMDATES3', 'DEP2YRS1', 'NPIQINF-4', 'NITE0',
#        'AGIT-4', 'ANX-4', 'APP-4', 'TRAILBLI', 'NITE-4', 'NACCAC1',
#        'ELAT-4', 'IRR1', 'TOBAC1001', 'SHOPPING-4', 'PACKSPER5', 'APA-4',
#        'DISN-4', 'ALCOCCAS1', 'UDSVERLN', 'MOT-4', 'NACCNIHR6',
#        'PRIMLANG1', 'PSYCDIS2', 'NACCANGI1', 'INSEX2', 'BPSYS', 'DEL0',
#        'ALCFREQ0', 'APNEA1', 'CVHATT2', 'NACCAPOE5', 'INCONTU1',
#        'DELSEV-4', 'DELSEV1', 'RBD1', 'NITESEV3', 'ANYMEDS1',
#        'HYPERCHO-4', 'SEIZURES2', 'TRAVEL3', 'NACCNINR5', 'EVENTS3',
#        'PRIMLANG4', 'ANXSEV3', 'ELATSEV3', 'SCHIZ1', 'ARTHTYPE-4',
#        'DEPD1', 'NPIQINF2', 'ARTHRIT0', 'CSFTTAU', 'CSFPTMD1.0',
#        'ALCFREQ3', 'APPSEV3', 'DIABTYPE-4', 'CVPACE2', 'TIAMULT-4',
#        'CVANGIO2', 'PRIMLANG-4', 'INRELTO3', 'HISPANIC-4', 'STROKMUL-4',
#        'NACCAPOE2', 'TBIEXTEN1', 'TRAUMBRF0', 'ARTHTYPE3', 'NACCNIHR3',
#        'PAYATTN3', 'ARTHUNK1', 'HISPANIC0', 'INRELTO7', 'ANYMEDS-4',
#        'NITESEV-4', 'IRRSEV1', 'CVHVALVE1', 'APNEA2', 'CVPACDEF2',
#        'ARTHUPEX0', 'CSFABMD-4', 'ARTHRIT2', 'NACCHTNC1', 'NACCNINR2',
#        'REMDATES-4', 'CVPACDEF1', 'ARTHTYPE1', 'RBD2', 'TBI2',
#        'DIABTYPE3', 'TRAUMEXT1', 'OTHSLEEP2', 'CSFPTMD-4.0', 'EVENTS-4',
#        'SCHIZ2', 'OCD1', 'ALCOHOL1', 'CVHVALVE-4', 'PTSD-4', 'HISPOR4',
#        'NACCANGI-4', 'PRIMLANG3', 'NACCACEI-4', 'ALCFREQ4', 'OTHSLEEP1',
#        'TBIWOLOS1', 'MEALPREP0', 'ARTHUPEX1', 'NACCEPMD1', 'CVANGINA2',
#        'NCOTHR2', 'UDSBENRS-4', 'CVAFIB-4', 'NACCAPOE6', 'BIPOLAR2',
#        'PRIMLANG6', 'NACCHTNC-4', 'NACCNSD-4', 'TBIWOLOS2', 'NACCDIUR-4',
#        'NACCEMD-4', 'NACCAAAS-4', 'APNEA-4', 'OCD2', 'CSFTTMD-4.0',
#        'STROKMUL0', 'DEPDSEV-4', 'HISPOR-4', 'NACCNINR6', 'TBI-4',
#        'CVBYPASS1', 'ARTHSPIN1', 'PTSD1', 'INSOMN-4', 'NACCAHTN-4',
#        'ALCFREQ1', 'STROKMUL1', 'ELATSEV2', 'INCONTU2', 'ABUSOTHR2',
#        'TRAUMEXT2', 'CVOTHR-4', 'CSFTTMD2.0', 'IRRSEV2', 'DISNSEV3',
#        'BIPOLAR1', 'PRIMLANG2', 'NACCVASD1', 'CVPACE0', 'NPSYDEV2',
#        'CSFTTMD1.0', 'NACCEPMD-4', 'NACCADEP-4', 'CRAFTCUE-4',
#        'TBIBRIEF1', 'NACCNINR4', 'MOTSEV3', 'PRIMLANG5', 'CSFPTMD2.0',
#        'INSOMN2', 'SCHIZ-4', 'TBIWOLOS-4', 'TBIBRIEF-4', 'ARTHUPEX-4',
#        'BIPOLAR-4', 'CVOTHR0', 'ARTHRIT-4', 'INSOMN1', 'TRAUMCHR2',
#        'DEP2YRS-4', 'NPSYDEV1', 'DEPOTHR-4', 'HISPOR6', 'HALLSEV1',
#        'TBI1', 'NACCNIHR4', 'INCONTF2', 'ARTHTYPE2', 'HISPOR3',
#        'TBIEXTEN2', 'NACCAC-4', 'CVHATT1', 'DIABTYPE1', 'NPSYDEV-4',
#        'CBSTROKE-4', 'OCD-4', 'IRRSEV3', 'NACCBETA-4', 'NACCLIPL-4',
#        'NACCAANX-4', 'HISPOR5', 'CSFABMD2', 'TIAMULT0', 'CVCHF1',
#        'OTHSLEEP-4', 'ABUSOTHR1', 'ARTHLOEX-4', 'ARTHSPIN-4', 'ARTHUNK-4',
#        'DIABETES2', 'CVANGINA1', 'CVPACDEF-4', 'HATTMULT0', 'NACCCCBS-4',
#        'NACCVASD-4', 'HISPOR2', 'HATTMULT1', 'NACCTBI0', 'ANXIETY-4',
#        'ARTHLOEX1', 'CVANGINA-4', 'TRAUMBRF1', 'HISPOR50', 'NACCAPSY-4',
#        'DIABTYPE2', 'RBD-4', 'ALCOCCAS-4', 'TBIBRIEF2', 'TBIEXTEN-4',
#        'NACCNINR3', 'PTSD2', 'CBSTROKE1', 'HALLSEV3', 'ANXIETY2',
#        'CSFABMD1', 'CVHVALVE2', 'NACCNIHR-4', 'ARTHLOEX0', 'TRAUMCHR-4',
#        'INSOMN0', 'ALCFREQ2', 'CVAFIB1', 'ANYMEDS0', 'NACCEMD1',
#        'TIAMULT1', 'NACCFAM-4', 'ALCOCCAS0', 'SEIZURES1', 'PSYCDIS1',
#        'B12DEF2', 'NACCDBMD-4', 'ABUSOTHR0', 'CBTIA-4', 'DEPD0',
#        'INRELTO6', 'APNEA0', 'PAYATTN-4', 'NACCNE4S1', 'CVOTHR1',
#        'STOVE3', 'ARTHRIT1', 'HATTMULT-4', 'EVENTS2', 'SHOPPING1',
#        'ANXIETY1', 'CBTIA1', 'NCOTHR-4', 'NACCNIHR5', 'HYPERCHO0',
#        'TRAUMCHR0', 'ALCFREQ-4', 'ALCOHOL-4', 'CVBYPASS0', 'CVPACE-4',
#        'EVENTS0', 'SEIZURES-4', 'TAXES1', 'TOBAC301', 'CVANGIO0',
#        'AGITSEV3', 'UDSBENRS0', 'CVCHF2', 'NACCTBI1', 'ARTHUNK0',
#        'NACCEPMD0', 'HISPANIC1', 'ANX0', 'HYPERCHO2', 'ANXIETY0',
#        'INSEX-4', 'BIPOLAR0', 'PSYCDIS0', 'INRELTO-4', 'RBD0', 'DEPDSEV3',
#        'DEL1', 'CVHATT0', 'NACCVASD0', 'CVBYPASS-4', 'NACCEMD0',
#        'INCONTU-4', 'IRR0', 'DIABETES-4', 'B12DEF0', 'APPSEV2', 'CVCHF-4',
#        'DELSEV3', 'CVBYPASS2', 'NCOTHR1', 'TOBAC30-4', 'AGITSEV2',
#        'OTHSLEEP0', 'DELSEV2', 'CVHATT-4', 'NACCNIHR1', 'B12DEF-4',
#        'NACCTBI-4', 'STOVE2', 'THYROID2', 'SCHIZ0', 'CVHVALVE0',
#        'NACCHTNC0', 'NACCNIHR2', 'CVPACE1', 'SHOPPING0', 'TRAUMEXT0',
#        'STOVE-4', 'HYPERCHO1', 'TBIWOLOS0', 'CVANGINA0', 'CVCHF0',
#        'TRAUMEXT-4', 'HISPOR1', 'TRAUMBRF-4', 'ELAT0', 'IRRSEV-4',
#        'NACCANGI0', 'INCONTF-4', 'NPSYDEV0', 'MOT0', 'PTSD0', 'ARTHSPIN0',
#        'ALCOHOL0', 'THYROID-4', 'NACCNINR-4', 'CVANGIO-4', 'OCD0',
#        'ABUSOTHR-4', 'ELATSEV-4', 'HYPERTEN-4', 'PSYCDIS-4', 'TAXES3',
#        'CBTIA0', 'NITE1', 'TBIEXTEN0', 'NITESEV1', 'UDSVERTE',
#        'CVPACDEF0', 'ANXSEV1', 'APASEV3', 'EVENTS1', 'SEIZURES0',
#        'INRELTO4', 'THYROID0', 'TRAVEL2', 'NITESEV2', 'NCOTHR0',
#        'INCONTF0', 'TOBAC100-4', 'ANXSEV-4', 'DEP2YRS0', 'TBIBRIEF0',
#        'AGIT0', 'REMDATES2', 'TOBAC300', 'NACCAPOE1', 'APP0', 'TAXES-4',
#        'HYPERTEN2', 'MINTSCNG', 'APPSEV-4', 'PACKSPER4', 'TBI0',
#        'CRAFTCUE0', 'STOVE0', 'NACCAC0', 'AGITSEV-4', 'CSFPTAU',
#        'MOTSEV-4', 'NACCAANX0', 'NACCNE4S2', 'NACCAPOE4', 'UDSBENRS1',
#        'GAMES1', 'TRAUMBRF2', 'INRELTO2', 'CRAFTCUE1', 'MEALPREP2',
#        'CVOTHR2', 'NACCNSD1', 'NACCAAAS0', 'DIGBACCT', 'CVAFIB0',
#        'NACCACEI0', 'NACCAPSY0', 'NACCCCBS0', 'BILLS-4', 'NACCFAM1',
#        'DIGFORSL', 'TOBAC1000', 'UDSVERTN', 'REMDATES1', 'PACKSPER0',
#        'NACCDBMD0', 'NACCLIPL0', 'SEX2', 'APA0', 'NACCNINR1', 'DEPDSEV1',
#        'MINTPCNG', 'INCONTU0', 'APASEV-4', 'PACKSPER1', 'GAMES-4',
#        'INRELTO5', 'INSEX1', 'NACCBETA0', 'BILLS3', 'DIGBACLS',
#        'UDSVERFC', 'DEPOTHR0', 'CRAFTDTI', 'ANIMALS', 'HALL1',
#        'NACCADEP0', 'DIGIB', 'DISNSEV-4', 'TRAVEL1', 'DIABETES0',
#        'NACCDIUR0', 'PAYATTN1', 'DIGIBLEN', 'UDSVERFN', 'HYPERTEN0',
#        'NACCAGEB', 'MINTSCNC', 'CBSTROKE0', 'DIGFORCT', 'INEDUC',
#        'MEALPREP-4', 'NACCAHTN0', 'TRAILARR', 'SHOPPING2', 'NPIQINF1',
#        'TRAILA', 'INRELTO1', 'EDUC', 'DIGIF', 'BOSTON', 'NACCAGE',
#        'TRAILB', 'NACCAMD', 'DISN0', 'CDRSUM'], dtype='<U11')

# %%
# to see the top 10 factors which is most important for each 
print("for PURE AD:", pure_alz_feature_names_importance[:10], "\n")
print("for PURE LBD:", pure_lbd_feature_names_importance[:10], "\n")
print("for MIX AD+LBD:", mix_feature_names_importance[:10], "\n")
print("for OTHERS:", others_feature_names_importance[:10])
# Out:
# for PURE AD: ['NACCAGE' 'SEX2' 'WAIS' 'UDSVERLC' 'CSFPTAU' 'NITE0' 'HALL0' 'NACCADEP0'
#  'NACCAPOE2' 'NACCNE4S1']
#
# for PURE LBD: ['HALL1' 'NACCAANX1' 'BOSTON' 'NACCMMSE' 'TRAILA' 'NITE1' 'SEX1'
#  'INRELTO1' 'TRAILB' 'MEMUNITS']
#
# for MIX AD+LBD: ['CDRSUM' 'EDUC' 'NACCAGE' 'BOSTON' 'NACCAGEB' 'DIGIF' 'HYPERCHO1'
#        -1.54907012e-03, -1.56960078e-03, -1.57756556e-03, -1.58209703e-03,
#        -1.58777169e-03, -1.60121790e-03, -1.65071455e-03, -1.70037220e-03,
#        -1.70886668e-03, -1.72798254e-03, -1.73726841e-03, -1.76810962e-03,
#        -1.84104999e-03, -1.85151503e-03, -1.86154933e-03, -1.86478917e-03,
#        -1.88840309e-03, -1.94189674e-03, -1.94442400e-03, -2.00946000e-03,
#        -2.05126195e-03, -2.12014164e-03, -2.15896568e-03, -2.16389261e-03,
#        -2.16746517e-03, -2.16895482e-03, -2.23916350e-03, -2.24346947e-03,
#        -2.27595912e-03, -2.27720407e-03, -2.32846220e-03, -2.34953011e-03,
#        -2.35246844e-03, -2.35964521e-03, -2.36134673e-03, -2.53338809e-03,
#        -2.54853303e-03, -2.60302122e-03, -2.71788030e-03, -2.75824848e-03,
#        -2.95337150e-03, -2.98111490e-03, -2.98728095e-03, -3.00870975e-03,
#        -3.12579889e-03, -3.16438382e-03, -3.20142927e-03, -3.22421151e-03,
#        -3.24778212e-03, -3.46708810e-03, -3.62409558e-03, -3.72514524e-03,
#        -3.75616178e-03, -3.86135629e-03, -4.11438895e-03, -4.24801186e-03,
#        -4.39913245e-03, -4.57252376e-03, -4.57279989e-03, -4.60792519e-03,
#        -4.81495075e-03, -5.01882890e-03, -5.20436140e-03, -5.29119326e-03,
#        -5.37359901e-03, -5.76729188e-03, -6.01130771e-03, -6.36803266e-03,
#        -6.63133385e-03, -6.66847359e-03, -6.70714071e-03, -6.88942289e-03,
#        -7.64005585e-03, -7.78978923e-03, -8.65078159e-03, -9.51125659e-03,
#        -1.02965022e-02, -1.03892069e-02, -1.06871855e-02, -1.08484151e-02,
#        -1.10960873e-02, -1.23984292e-02, -1.28808133e-02, -1.31567391e-02,
#        -1.41569003e-02, -1.42162684e-02, -1.43201333e-02, -2.09724307e-02,
#        -6.17802665e-02, -8.46324265e-02, -9.48300138e-02, -1.03231609e-01,
#        -1.08034074e-01, -1.19516455e-01, -1.52794421e-01, -1.78978279e-01,
#        -3.62657547e-01], dtype=float32)

# %%
# get the most important factors whose weights are at the magnitude of e-1
print("for PURE AD:", pure_alz_feature_names_importance[:3], "\n")
print("for PURE LBD:", pure_lbd_feature_names_importance[:8], "\n")
print("for MIX AD+LBD:", mix_feature_names_importance[:3], "\n")
print("for OTHERS:", others_feature_names_importance[:2])
# Out:
# for PURE AD: ['NACCAGE' 'SEX2' 'WAIS']
#
# for PURE LBD: ['HALL1' 'NACCAANX1' 'BOSTON' 'NACCMMSE' 'TRAILA' 'NITE1' 'SEX1'
#  'INRELTO1']
#
# for MIX AD+LBD: ['CDRSUM' 'EDUC' 'NACCAGE']
#
# for OTHERS: ['WAIS' 'NACCNE4S0']

# %%
mix_feature_names_importance[:11]
# Out:
# array(['CDRSUM', 'EDUC', 'NACCAGE', 'BOSTON', 'NACCAGEB', 'DIGIF',
#        'HYPERCHO1', 'TRAILA', 'TRAILB', 'HALL1', 'HALLSEV1'], dtype='<U11')
